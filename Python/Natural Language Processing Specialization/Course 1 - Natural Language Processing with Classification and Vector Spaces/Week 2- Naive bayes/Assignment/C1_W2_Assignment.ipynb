# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiment.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %% [markdown]
# ## Table of Contents
#
# - [Importing Functions and Data](#0)
# - [1 - Process the Data](#1)
#     - [1.1 - Implementing your Helper Functions](#1-1)
#         - [Exercise 1 - count_tweets (UNQ_C1)](#ex-1)
# - [2 - Train your Model using Naive Bayes](#2)
#     - [Exercise 2 - train_naive_bayes (UNQ_C2)](#ex-2)
# - [3 - Test your Naive Bayes](#3)
#     - [Exercise 3 - naive_bayes_predict  (UNQ_C4)](#ex-3)
#     - [Exercise 4 - test_naive_bayes (UNQ_C6)](#ex-4)
# - [4 - Filter words by Ratio of Positive to Negative Counts](#4)
#     - [Exercise 5 - get_ratio (UNQ_C8)](#ex-5)
#     - [Exercise 6 - get_words_by_threshold (UNQ_C9)](#ex-6)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Importing Functions and Data

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd
import w2_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jyang/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jyang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the tweeter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# <a name='1'></a>
# ## 1 - Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Implementing your Helper Functions
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2,
#     ("happi", 1) : 1,
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# <a name='ex-1'></a>
# ### Exercise 1 - count_tweets
# Create a function `count_tweets` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: count_tweets

def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    ### START CODE HERE ###
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word, y)
            
            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
    ### END CODE HERE ###

    return result

# %%
# Testing your function

result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
# Test your function
w2_unittest.test_count_tweets(count_tweets)
# Out:
#  All tests passed

# %% [markdown]
# <a name='2'></a>
# ## 2 - Train your Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %%
list(freqs.keys())
# Out:
# [('followfriday', np.float64(1.0)),
#  ('top', np.float64(1.0)),
#  ('engag', np.float64(1.0)),
#  ('member', np.float64(1.0)),
#  ('commun', np.float64(1.0)),
#  ('week', np.float64(1.0)),
#  (':)', np.float64(1.0)),
#  ('hey', np.float64(1.0)),
#  ('jame', np.float64(1.0)),
#  ('odd', np.float64(1.0)),
#  (':/', np.float64(1.0)),
#  ('pleas', np.float64(1.0)),
#  ('call', np.float64(1.0)),
#  ('contact', np.float64(1.0)),
#  ('centr', np.float64(1.0)),
#  ('02392441234', np.float64(1.0)),
#  ('abl', np.float64(1.0)),
#  ('assist', np.float64(1.0)),
#  ('mani', np.float64(1.0)),
#  ('thank', np.float64(1.0)),
#  ('listen', np.float64(1.0)),
#  ('last', np.float64(1.0)),
#  ('night', np.float64(1.0)),
#  ('bleed', np.float64(1.0)),
#  ('amaz', np.float64(1.0)),
#  ('track', np.float64(1.0)),
#  ('scotland', np.float64(1.0)),
#  ('congrat', np.float64(1.0)),
#  ('yeaaah', np.float64(1.0)),
#  ('yipppi', np.float64(1.0)),
#  ('accnt', np.float64(1.0)),
#  ('verifi', np.float64(1.0)),
#  ('rqst', np.float64(1.0)),
#  ('succeed', np.float64(1.0)),
#  ('got', np.float64(1.0)),
#  ('blue', np.float64(1.0)),
#  ('tick', np.float64(1.0)),
#  ('mark', np.float64(1.0)),
#  ('fb', np.float64(1.0)),
#  ('profil', np.float64(1.0)),
#  ('15', np.float64(1.0)),
#  ('day', np.float64(1.0)),
#  ('one', np.float64(1.0)),
#  ('irresist', np.float64(1.0)),
#  ('flipkartfashionfriday', np.float64(1.0)),
#  ('like', np.float64(1.0)),
#  ('keep', np.float64(1.0)),
#  ('love', np.float64(1.0)),
#  ('custom', np.float64(1.0)),
#  ('wait', np.float64(1.0)),
#  ('long', np.float64(1.0)),
#  ('hope', np.float64(1.0)),
#  ('enjoy', np.float64(1.0)),
#  ('happi', np.float64(1.0)),
#  ('friday', np.float64(1.0)),
#  ('lwwf', np.float64(1.0)),
#  ('second', np.float64(1.0)),
#  ('thought', np.float64(1.0)),
#  ('’', np.float64(1.0)),
#  ('enough', np.float64(1.0)),
#  ('time', np.float64(1.0)),
#  ('dd', np.float64(1.0)),
#  ('new', np.float64(1.0)),
#  ('short', np.float64(1.0)),
#  ('enter', np.float64(1.0)),
#  ('system', np.float64(1.0)),
#  ('sheep', np.float64(1.0)),
#  ('must', np.float64(1.0)),
#  ('buy', np.float64(1.0)),
#  ('jgh', np.float64(1.0)),
#  ('go', np.float64(1.0)),
#  ('bayan', np.float64(1.0)),
#  (':d', np.float64(1.0)),
#  ('bye', np.float64(1.0)),
#  ('act', np.float64(1.0)),
#  ('mischiev', np.float64(1.0)),
#  ('etl', np.float64(1.0)),
#  ('layer', np.float64(1.0)),
#  ('in-hous', np.float64(1.0)),
#  ('wareh', np.float64(1.0)),
#  ('app', np.float64(1.0)),
#  ('katamari', np.float64(1.0)),
#  ('well', np.float64(1.0)),
#  ('…', np.float64(1.0)),
#  ('name', np.float64(1.0)),
#  ('impli', np.float64(1.0)),
#  (':p', np.float64(1.0)),
#  ('influenc', np.float64(1.0)),
#  ('big', np.float64(1.0)),
#  ('...', np.float64(1.0)),
#  ('juici', np.float64(1.0)),
#  ('selfi', np.float64(1.0)),
#  ('follow', np.float64(1.0)),
#  ('u', np.float64(1.0)),
#  ('back', np.float64(1.0)),
#  ('perfect', np.float64(1.0)),
#  ('alreadi', np.float64(1.0)),
#  ('know', np.float64(1.0)),
#  ("what'", np.float64(1.0)),
#  ('great', np.float64(1.0)),
#  ('opportun', np.float64(1.0)),
#  ('junior', np.float64(1.0)),
#  ('triathlet', np.float64(1.0)),
#  ('age', np.float64(1.0)),
#  ('12', np.float64(1.0)),
#  ('13', np.float64(1.0)),
#  ('gatorad', np.float64(1.0)),
#  ('seri', np.float64(1.0)),
#  ('get', np.float64(1.0)),
#  ('entri', np.float64(1.0)),
#  ('lay', np.float64(1.0)),
#  ('greet', np.float64(1.0)),
#  ('card', np.float64(1.0)),
#  ('rang', np.float64(1.0)),
#  ('print', np.float64(1.0)),
#  ('today', np.float64(1.0)),
#  ('job', np.float64(1.0)),
#  (':-)', np.float64(1.0)),
#  ("friend'", np.float64(1.0)),
#  ('lunch', np.float64(1.0)),
#  ('yummm', np.float64(1.0)),
#  ('nostalgia', np.float64(1.0)),
#  ('tb', np.float64(1.0)),
#  ('ku', np.float64(1.0)),
#  ('id', np.float64(1.0)),
#  ('conflict', np.float64(1.0)),
#  ('help', np.float64(1.0)),
#  ("here'", np.float64(1.0)),
#  ('screenshot', np.float64(1.0)),
#  ('work', np.float64(1.0)),
#  ('hi', np.float64(1.0)),
#  ('liv', np.float64(1.0)),
#  ('hello', np.float64(1.0)),
#  ('need', np.float64(1.0)),
#  ('someth', np.float64(1.0)),
#  ('fm', np.float64(1.0)),
#  ('twitter', np.float64(1.0)),
#  ('—', np.float64(1.0)),
#  ('sure', np.float64(1.0)),
#  ('thing', np.float64(1.0)),
#  ('dm', np.float64(1.0)),
#  ('x', np.float64(1.0)),
#  ("i'v", np.float64(1.0)),
#  ('heard', np.float64(1.0)),
#  ('four', np.float64(1.0)),
#  ('season', np.float64(1.0)),
#  ('pretti', np.float64(1.0)),
#  ('dope', np.float64(1.0)),
#  ('penthous', np.float64(1.0)),
#  ('obv', np.float64(1.0)),
#  ('gobigorgohom', np.float64(1.0)),
#  ('fun', np.float64(1.0)),
#  ("y'all", np.float64(1.0)),
#  ('yeah', np.float64(1.0)),
#  ('suppos', np.float64(1.0)),
#  ('lol', np.float64(1.0)),
#  ('chat', np.float64(1.0)),
#  ('bit', np.float64(1.0)),
#  ('youth', np.float64(1.0)),
#  ('💅🏽', np.float64(1.0)),
#  ('💋', np.float64(1.0)),
#  ('seen', np.float64(1.0)),
#  ('year', np.float64(1.0)),
#  ('rest', np.float64(1.0)),
#  ('goe', np.float64(1.0)),
#  ('quickli', np.float64(1.0)),
#  ('bed', np.float64(1.0)),
#  ('music', np.float64(1.0)),
#  ('fix', np.float64(1.0)),
#  ('dream', np.float64(1.0)),
#  ('spiritu', np.float64(1.0)),
#  ('ritual', np.float64(1.0)),
#  ('festiv', np.float64(1.0)),
#  ('népal', np.float64(1.0)),
#  ('begin', np.float64(1.0)),
#  ('line-up', np.float64(1.0)),
#  ('left', np.float64(1.0)),
#  ('see', np.float64(1.0)),
#  ('sarah', np.float64(1.0)),
#  ('send', np.float64(1.0)),
#  ('us', np.float64(1.0)),
#  ('email', np.float64(1.0)),
#  ('bitsy@bitdefender.com', np.float64(1.0)),
#  ("we'll", np.float64(1.0)),
#  ('asap', np.float64(1.0)),
#  ('kik', np.float64(1.0)),
#  ('hatessuc', np.float64(1.0)),
#  ('32429', np.float64(1.0)),
#  ('kikm', np.float64(1.0)),
#  ('lgbt', np.float64(1.0)),
#  ('tinder', np.float64(1.0)),
#  ('nsfw', np.float64(1.0)),
#  ('akua', np.float64(1.0)),
#  ('cumshot', np.float64(1.0)),
#  ('come', np.float64(1.0)),
#  ('hous', np.float64(1.0)),
#  ('nsn_supplement', np.float64(1.0)),
#  ('effect', np.float64(1.0)),
#  ('press', np.float64(1.0)),
#  ('releas', np.float64(1.0)),
#  ('distribut', np.float64(1.0)),
#  ('result', np.float64(1.0)),
#  ('link', np.float64(1.0)),
#  ('remov', np.float64(1.0)),
#  ('pressreleas', np.float64(1.0)),
#  ('newsdistribut', np.float64(1.0)),
#  ('bam', np.float64(1.0)),
#  ('bestfriend', np.float64(1.0)),
#  ('lot', np.float64(1.0)),
#  ('warsaw', np.float64(1.0)),
#  ('<3', np.float64(1.0)),
#  ('x46', np.float64(1.0)),
#  ('everyon', np.float64(1.0)),
#  ('watch', np.float64(1.0)),
#  ('documentari', np.float64(1.0)),
#  ('earthl', np.float64(1.0)),
#  ('youtub', np.float64(1.0)),
#  ('support', np.float64(1.0)),
#  ('buuut', np.float64(1.0)),
#  ('oh', np.float64(1.0)),
#  ('look', np.float64(1.0)),
#  ('forward', np.float64(1.0)),
#  ('visit', np.float64(1.0)),
#  ('next', np.float64(1.0)),
#  ('letsgetmessi', np.float64(1.0)),
#  ('jo', np.float64(1.0)),
#  ('make', np.float64(1.0)),
#  ('feel', np.float64(1.0)),
#  ('better', np.float64(1.0)),
#  ('never', np.float64(1.0)),
#  ('anyon', np.float64(1.0)),
#  ('kpop', np.float64(1.0)),
#  ('flesh', np.float64(1.0)),
#  ('good', np.float64(1.0)),
#  ('girl', np.float64(1.0)),
#  ('best', np.float64(1.0)),
#  ('wish', np.float64(1.0)),
#  ('reason', np.float64(1.0)),
#  ('epic', np.float64(1.0)),
#  ('soundtrack', np.float64(1.0)),
#  ('shout', np.float64(1.0)),
#  ('ad', np.float64(1.0)),
#  ('video', np.float64(1.0)),
#  ('playlist', np.float64(1.0)),
#  ('im', np.float64(1.0)),
#  ('twitch', np.float64(1.0)),
#  ('leagu', np.float64(1.0)),
#  ('1', np.float64(1.0)),
#  ('4', np.float64(1.0)),
#  ('would', np.float64(1.0)),
#  ('dear', np.float64(1.0)),
#  ('jordan', np.float64(1.0)),
#  ('okay', np.float64(1.0)),
#  ('fake', np.float64(1.0)),
#  ('gameplay', np.float64(1.0)),
#  (';)', np.float64(1.0)),
#  ('haha', np.float64(1.0)),
#  ('kid', np.float64(1.0)),
#  ('stuff', np.float64(1.0)),
#  ('exactli', np.float64(1.0)),
#  ('product', np.float64(1.0)),
#  ('line', np.float64(1.0)),
#  ('etsi', np.float64(1.0)),
#  ('shop', np.float64(1.0)),
#  ('check', np.float64(1.0)),
#  ('boxroomcraft', np.float64(1.0)),
#  ('vacat', np.float64(1.0)),
#  ('recharg', np.float64(1.0)),
#  ('normal', np.float64(1.0)),
#  ('charger', np.float64(1.0)),
#  ('asleep', np.float64(1.0)),
#  ('talk', np.float64(1.0)),
#  ('sooo', np.float64(1.0)),
#  ('someon', np.float64(1.0)),
#  ('text', np.float64(1.0)),
#  ('ye', np.float64(1.0)),
#  ('bet', np.float64(1.0)),
#  ("he'll", np.float64(1.0)),
#  ('fit', np.float64(1.0)),
#  ('hear', np.float64(1.0)),
#  ('speech', np.float64(1.0)),
#  ('piti', np.float64(1.0)),
#  ('green', np.float64(1.0)),
#  ('garden', np.float64(1.0)),
#  ('midnight', np.float64(1.0)),
#  ('sun', np.float64(1.0)),
#  ('beauti', np.float64(1.0)),
#  ('canal', np.float64(1.0)),
#  ('dasvidaniya', np.float64(1.0)),
#  ('till', np.float64(1.0)),
#  ('scout', np.float64(1.0)),
#  ('sg', np.float64(1.0)),
#  ('futur', np.float64(1.0)),
#  ('wlan', np.float64(1.0)),
#  ('pro', np.float64(1.0)),
#  ('confer', np.float64(1.0)),
#  ('asia', np.float64(1.0)),
#  ('chang', np.float64(1.0)),
#  ('lollipop', np.float64(1.0)),
#  ('🍭', np.float64(1.0)),
#  ('nez', np.float64(1.0)),
#  ('agnezmo', np.float64(1.0)),
#  ('oley', np.float64(1.0)),
#  ('mama', np.float64(1.0)),
#  ('stand', np.float64(1.0)),
#  ('stronger', np.float64(1.0)),
#  ('god', np.float64(1.0)),
#  ('misti', np.float64(1.0)),
#  ('babi', np.float64(1.0)),
#  ('cute', np.float64(1.0)),
#  ('woohoo', np.float64(1.0)),
#  ("can't", np.float64(1.0)),
#  ('sign', np.float64(1.0)),
#  ('yet', np.float64(1.0)),
#  ('still', np.float64(1.0)),
#  ('think', np.float64(1.0)),
#  ('mka', np.float64(1.0)),
#  ('liam', np.float64(1.0)),
#  ('access', np.float64(1.0)),
#  ('welcom', np.float64(1.0)),
#  ('stat', np.float64(1.0)),
#  ('arriv', np.float64(1.0)),
#  ('unfollow', np.float64(1.0)),
#  ('via', np.float64(1.0)),
#  ('surpris', np.float64(1.0)),
#  ('figur', np.float64(1.0)),
#  ('happybirthdayemilybett', np.float64(1.0)),
#  ('sweet', np.float64(1.0)),
#  ('talent', np.float64(1.0)),
#  ('2', np.float64(1.0)),
#  ('plan', np.float64(1.0)),
#  ('drain', np.float64(1.0)),
#  ('gotta', np.float64(1.0)),
#  ('timezon', np.float64(1.0)),
#  ('parent', np.float64(1.0)),
#  ('proud', np.float64(1.0)),
#  ('least', np.float64(1.0)),
#  ('mayb', np.float64(1.0)),
#  ('sometim', np.float64(1.0)),
#  ('grade', np.float64(1.0)),
#  ('al', np.float64(1.0)),
#  ('grand', np.float64(1.0)),
#  ('manila_bro', np.float64(1.0)),
#  ('chosen', np.float64(1.0)),
#  ('let', np.float64(1.0)),
#  ('around', np.float64(1.0)),
#  ('..', np.float64(1.0)),
#  ('side', np.float64(1.0)),
#  ('world', np.float64(1.0)),
#  ('eh', np.float64(1.0)),
#  ('take', np.float64(1.0)),
#  ('care', np.float64(1.0)),
#  ('final', np.float64(1.0)),
#  ('fuck', np.float64(1.0)),
#  ('weekend', np.float64(1.0)),
#  ('real', np.float64(1.0)),
#  ('x45', np.float64(1.0)),
#  ('join', np.float64(1.0)),
#  ('hushedcallwithfraydo', np.float64(1.0)),
#  ('gift', np.float64(1.0)),
#  ('yeahhh', np.float64(1.0)),
#  ('hushedpinwithsammi', np.float64(1.0)),
#  ('event', np.float64(1.0)),
#  ('might', np.float64(1.0)),
#  ('luv', np.float64(1.0)),
#  ('realli', np.float64(1.0)),
#  ('appreci', np.float64(1.0)),
#  ('share', np.float64(1.0)),
#  ('wow', np.float64(1.0)),
#  ('tom', np.float64(1.0)),
#  ('3', np.float64(1.0)),
#  ('gym', np.float64(1.0)),
#  ('monday', np.float64(1.0)),
#  ('invit', np.float64(1.0)),
#  ('scope', np.float64(1.0)),
#  ('friend', np.float64(1.0)),
#  ('nude', np.float64(1.0)),
#  ('sleep', np.float64(1.0)),
#  ('birthday', np.float64(1.0)),
#  ('want', np.float64(1.0)),
#  ('t-shirt', np.float64(1.0)),
#  ('cool', np.float64(1.0)),
#  ('haw', np.float64(1.0)),
#  ('phela', np.float64(1.0)),
#  ('mom', np.float64(1.0)),
#  ('obvious', np.float64(1.0)),
#  ('princ', np.float64(1.0)),
#  ('charm', np.float64(1.0)),
#  ('stage', np.float64(1.0)),
#  ('luck', np.float64(1.0)),
#  ('tyler', np.float64(1.0)),
#  ('hipster', np.float64(1.0)),
#  ('glass', np.float64(1.0)),
#  ('marti', np.float64(1.0)),
#  ('glad', np.float64(1.0)),
#  ('done', np.float64(1.0)),
#  ('afternoon', np.float64(1.0)),
#  ('read', np.float64(1.0)),
#  ('kahfi', np.float64(1.0)),
#  ('finish', np.float64(1.0)),
#  ('ohmyg', np.float64(1.0)),
#  ('yaya', np.float64(1.0)),
#  ('dub', np.float64(1.0)),
#  ('stalk', np.float64(1.0)),
#  ('ig', np.float64(1.0)),
#  ('gondooo', np.float64(1.0)),
#  ('moo', np.float64(1.0)),
#  ('tologooo', np.float64(1.0)),
#  ('becom', np.float64(1.0)),
#  ('detail', np.float64(1.0)),
#  ('zzz', np.float64(1.0)),
#  ('xx', np.float64(1.0)),
#  ('physiotherapi', np.float64(1.0)),
#  ('hashtag', np.float64(1.0)),
#  ('💪', np.float64(1.0)),
#  ('monica', np.float64(1.0)),
#  ('miss', np.float64(1.0)),
#  ('sound', np.float64(1.0)),
#  ('morn', np.float64(1.0)),
#  ("that'", np.float64(1.0)),
#  ('x43', np.float64(1.0)),
#  ('definit', np.float64(1.0)),
#  ('tri', np.float64(1.0)),
#  ('tonight', np.float64(1.0)),
#  ('took', np.float64(1.0)),
#  ('advic', np.float64(1.0)),
#  ('treviso', np.float64(1.0)),
#  ('concert', np.float64(1.0)),
#  ('citi', np.float64(1.0)),
#  ('countri', np.float64(1.0)),
#  ("i'll", np.float64(1.0)),
#  ('start', np.float64(1.0)),
#  ('fine', np.float64(1.0)),
#  ('gorgeou', np.float64(1.0)),
#  ('xo', np.float64(1.0)),
#  ('oven', np.float64(1.0)),
#  ('roast', np.float64(1.0)),
#  ('garlic', np.float64(1.0)),
#  ('oliv', np.float64(1.0)),
#  ('oil', np.float64(1.0)),
#  ('dri', np.float64(1.0)),
#  ('tomato', np.float64(1.0)),
#  ('basil', np.float64(1.0)),
#  ('centuri', np.float64(1.0)),
#  ('tuna', np.float64(1.0)),
#  ('right', np.float64(1.0)),
#  ('atchya', np.float64(1.0)),
#  ('even', np.float64(1.0)),
#  ('almost', np.float64(1.0)),
#  ('chanc', np.float64(1.0)),
#  ('cheer', np.float64(1.0)),
#  ('po', np.float64(1.0)),
#  ('ice', np.float64(1.0)),
#  ('cream', np.float64(1.0)),
#  ('agre', np.float64(1.0)),
#  ('100', np.float64(1.0)),
#  ('heheheh', np.float64(1.0)),
#  ('that', np.float64(1.0)),
#  ('point', np.float64(1.0)),
#  ('stay', np.float64(1.0)),
#  ('home', np.float64(1.0)),
#  ('soon', np.float64(1.0)),
#  ('promis', np.float64(1.0)),
#  ('web', np.float64(1.0)),
#  ('whatsapp', np.float64(1.0)),
#  ('volta', np.float64(1.0)),
#  ('funcionar', np.float64(1.0)),
#  ('com', np.float64(1.0)),
#  ('iphon', np.float64(1.0)),
#  ('jailbroken', np.float64(1.0)),
#  ('later', np.float64(1.0)),
#  ('34', np.float64(1.0)),
#  ('min', np.float64(1.0)),
#  ('leia', np.float64(1.0)),
#  ('appear', np.float64(1.0)),
#  ('hologram', np.float64(1.0)),
#  ('r2d2', np.float64(1.0)),
#  ('w', np.float64(1.0)),
#  ('messag', np.float64(1.0)),
#  ('obi', np.float64(1.0)),
#  ('wan', np.float64(1.0)),
#  ('sit', np.float64(1.0)),
#  ('luke', np.float64(1.0)),
#  ('inter', np.float64(1.0)),
#  ('ucl', np.float64(1.0)),
#  ('arsen', np.float64(1.0)),
#  ('small', np.float64(1.0)),
#  ('team', np.float64(1.0)),
#  ('pass', np.float64(1.0)),
#  ('🚂', np.float64(1.0)),
#  ('dewsburi', np.float64(1.0)),
#  ('railway', np.float64(1.0)),
#  ('station', np.float64(1.0)),
#  ('dew', np.float64(1.0)),
#  ('west', np.float64(1.0)),
#  ('yorkshir', np.float64(1.0)),
#  ('430', np.float64(1.0)),
#  ('smh', np.float64(1.0)),
#  ('9:25', np.float64(1.0)),
#  ('live', np.float64(1.0)),
#  ('strang', np.float64(1.0)),
#  ('imagin', np.float64(1.0)),
#  ('megan', np.float64(1.0)),
#  ('masaantoday', np.float64(1.0)),
#  ('a4', np.float64(1.0)),
#  ('shweta', np.float64(1.0)),
#  ('tripathi', np.float64(1.0)),
#  ('5', np.float64(1.0)),
#  ('20', np.float64(1.0)),
#  ('kurta', np.float64(1.0)),
#  ('half', np.float64(1.0)),
#  ('number', np.float64(1.0)),
#  ('wsalelov', np.float64(1.0)),
#  ('ah', np.float64(1.0)),
#  ('larri', np.float64(1.0)),
#  ('anyway', np.float64(1.0)),
#  ('kinda', np.float64(1.0)),
#  ('goood', np.float64(1.0)),
#  ('life', np.float64(1.0)),
#  ('enn', np.float64(1.0)),
#  ('could', np.float64(1.0)),
#  ('warmup', np.float64(1.0)),
#  ('15th', np.float64(1.0)),
#  ('bath', np.float64(1.0)),
#  ('dum', np.float64(1.0)),
#  ('andar', np.float64(1.0)),
#  ('ram', np.float64(1.0)),
#  ('sampath', np.float64(1.0)),
#  ('sona', np.float64(1.0)),
#  ('mohapatra', np.float64(1.0)),
#  ('samantha', np.float64(1.0)),
#  ('edward', np.float64(1.0)),
#  ('mein', np.float64(1.0)),
#  ('tulan', np.float64(1.0)),
#  ('razi', np.float64(1.0)),
#  ('wah', np.float64(1.0)),
#  ('josh', np.float64(1.0)),
#  ('alway', np.float64(1.0)),
#  ('smile', np.float64(1.0)),
#  ('pictur', np.float64(1.0)),
#  ('16.20', np.float64(1.0)),
#  ('giveitup', np.float64(1.0)),
#  ('given', np.float64(1.0)),
#  ('ga', np.float64(1.0)),
#  ('subsidi', np.float64(1.0)),
#  ('initi', np.float64(1.0)),
#  ('propos', np.float64(1.0)),
#  ('delight', np.float64(1.0)),
#  ('yesterday', np.float64(1.0)),
#  ('x42', np.float64(1.0)),
#  ('lmaoo', np.float64(1.0)),
#  ('song', np.float64(1.0)),
#  ('ever', np.float64(1.0)),
#  ('shall', np.float64(1.0)),
#  ('littl', np.float64(1.0)),
#  ('throwback', np.float64(1.0)),
#  ('outli', np.float64(1.0)),
#  ('island', np.float64(1.0)),
#  ('cheung', np.float64(1.0)),
#  ('chau', np.float64(1.0)),
#  ('mui', np.float64(1.0)),
#  ('wo', np.float64(1.0)),
#  ('total', np.float64(1.0)),
#  ('differ', np.float64(1.0)),
#  ('kfckitchentour', np.float64(1.0)),
#  ('kitchen', np.float64(1.0)),
#  ('clean', np.float64(1.0)),
#  ("i'm", np.float64(1.0)),
#  ('cusp', np.float64(1.0)),
#  ('test', np.float64(1.0)),
#  ('water', np.float64(1.0)),
#  ('reward', np.float64(1.0)),
#  ('arummzz', np.float64(1.0)),
#  ("let'", np.float64(1.0)),
#  ('drive', np.float64(1.0)),
#  ('travel', np.float64(1.0)),
#  ('yogyakarta', np.float64(1.0)),
#  ('jeep', np.float64(1.0)),
#  ('indonesia', np.float64(1.0)),
#  ('instamood', np.float64(1.0)),
#  ('wanna', np.float64(1.0)),
#  ('skype', np.float64(1.0)),
#  ('may', np.float64(1.0)),
#  ('nice', np.float64(1.0)),
#  ('friendli', np.float64(1.0)),
#  ('pretend', np.float64(1.0)),
#  ('film', np.float64(1.0)),
#  ('congratul', np.float64(1.0)),
#  ('winner', np.float64(1.0)),
#  ('cheesydelight', np.float64(1.0)),
#  ('contest', np.float64(1.0)),
#  ('address', np.float64(1.0)),
#  ('guy', np.float64(1.0)),
#  ('market', np.float64(1.0)),
#  ('24/7', np.float64(1.0)),
#  ('regret', np.float64(1.0)),
#  ('14', np.float64(1.0)),
#  ('hour', np.float64(1.0)),
#  ('leav', np.float64(1.0)),
#  ('without', np.float64(1.0)),
#  ('delay', np.float64(1.0)),
#  ('actual', np.float64(1.0)),
#  ('easi', np.float64(1.0)),
#  ('guess', np.float64(1.0)),
#  ('train', np.float64(1.0)),
#  ('wd', np.float64(1.0)),
#  ('shift', np.float64(1.0)),
#  ('engin', np.float64(1.0)),
#  ('etc', np.float64(1.0)),
#  ('sunburn', np.float64(1.0)),
#  ('peel', np.float64(1.0)),
#  ('blog', np.float64(1.0)),
#  ('huge', np.float64(1.0)),
#  ('warm', np.float64(1.0)),
#  ('☆', np.float64(1.0)),
#  ('complet', np.float64(1.0)),
#  ('triangl', np.float64(1.0)),
#  ('northern', np.float64(1.0)),
#  ('ireland', np.float64(1.0)),
#  ('sight', np.float64(1.0)),
#  ('smthng', np.float64(1.0)),
#  ('fr', np.float64(1.0)),
#  ('hug', np.float64(1.0)),
#  ('xoxo', np.float64(1.0)),
#  ('uu', np.float64(1.0)),
#  ('jaann', np.float64(1.0)),
#  ('topnewfollow', np.float64(1.0)),
#  ('connect', np.float64(1.0)),
#  ('wonder', np.float64(1.0)),
#  ('made', np.float64(1.0)),
#  ('fluffi', np.float64(1.0)),
#  ('insid', np.float64(1.0)),
#  ('pirouett', np.float64(1.0)),
#  ('moos', np.float64(1.0)),
#  ('trip', np.float64(1.0)),
#  ('philli', np.float64(1.0)),
#  ('decemb', np.float64(1.0)),
#  ("i'd", np.float64(1.0)),
#  ('dude', np.float64(1.0)),
#  ('x41', np.float64(1.0)),
#  ('question', np.float64(1.0)),
#  ('flaw', np.float64(1.0)),
#  ('pain', np.float64(1.0)),
#  ('negat', np.float64(1.0)),
#  ('strength', np.float64(1.0)),
#  ('went', np.float64(1.0)),
#  ('solo', np.float64(1.0)),
#  ('move', np.float64(1.0)),
#  ('fav', np.float64(1.0)),
#  ('nirvana', np.float64(1.0)),
#  ('smell', np.float64(1.0)),
#  ('teen', np.float64(1.0)),
#  ('spirit', np.float64(1.0)),
#  ('rip', np.float64(1.0)),
#  ('ami', np.float64(1.0)),
#  ('winehous', np.float64(1.0)),
#  ('coupl', np.float64(1.0)),
#  ('tomhiddleston', np.float64(1.0)),
#  ('elizabetholsen', np.float64(1.0)),
#  ('yaytheylookgreat', np.float64(1.0)),
#  ('goodnight', np.float64(1.0)),
#  ('vid', np.float64(1.0)),
#  ('wake', np.float64(1.0)),
#  ('gonna', np.float64(1.0)),
#  ('shoot', np.float64(1.0)),
#  ('itti', np.float64(1.0)),
#  ('bitti', np.float64(1.0)),
#  ('teeni', np.float64(1.0)),
#  ('bikini', np.float64(1.0)),
#  ('much', np.float64(1.0)),
#  ('4th', np.float64(1.0)),
#  ('togeth', np.float64(1.0)),
#  ('end', np.float64(1.0)),
#  ('xfile', np.float64(1.0)),
#  ('content', np.float64(1.0)),
#  ('rain', np.float64(1.0)),
#  ('fabul', np.float64(1.0)),
#  ('fantast', np.float64(1.0)),
#  ('♡', np.float64(1.0)),
#  ('jb', np.float64(1.0)),
#  ('forev', np.float64(1.0)),
#  ('belieb', np.float64(1.0)),
#  ('nighti', np.float64(1.0)),
#  ('bug', np.float64(1.0)),
#  ('bite', np.float64(1.0)),
#  ('bracelet', np.float64(1.0)),
#  ('idea', np.float64(1.0)),
#  ('foundri', np.float64(1.0)),
#  ('game', np.float64(1.0)),
#  ('sens', np.float64(1.0)),
#  ('pic', np.float64(1.0)),
#  ('ef', np.float64(1.0)),
#  ('phone', np.float64(1.0)),
#  ('woot', np.float64(1.0)),
#  ('derek', np.float64(1.0)),
#  ('use', np.float64(1.0)),
#  ('parkshar', np.float64(1.0)),
#  ('gloucestershir', np.float64(1.0)),
#  ('aaaahhh', np.float64(1.0)),
#  ('man', np.float64(1.0)),
#  ('traffic', np.float64(1.0)),
#  ('stress', np.float64(1.0)),
#  ('reliev', np.float64(1.0)),
#  ("how'r", np.float64(1.0)),
#  ('arbeloa', np.float64(1.0)),
#  ('turn', np.float64(1.0)),
#  ('17', np.float64(1.0)),
#  ('omg', np.float64(1.0)),
#  ('say', np.float64(1.0)),
#  ('europ', np.float64(1.0)),
#  ('rise', np.float64(1.0)),
#  ('find', np.float64(1.0)),
#  ('hard', np.float64(1.0)),
#  ('believ', np.float64(1.0)),
#  ('uncount', np.float64(1.0)),
#  ('coz', np.float64(1.0)),
#  ('unlimit', np.float64(1.0)),
#  ('cours', np.float64(1.0)),
#  ('teamposit', np.float64(1.0)),
#  ('aldub', np.float64(1.0)),
#  ('☕', np.float64(1.0)),
#  ('rita', np.float64(1.0)),
#  ('info', np.float64(1.0)),
#  ("we'd", np.float64(1.0)),
#  ('way', np.float64(1.0)),
#  ('boy', np.float64(1.0)),
#  ('x40', np.float64(1.0)),
#  ('true', np.float64(1.0)),
#  ('sethi', np.float64(1.0)),
#  ('high', np.float64(1.0)),
#  ('exe', np.float64(1.0)),
#  ('skeem', np.float64(1.0)),
#  ('saam', np.float64(1.0)),
#  ('peopl', np.float64(1.0)),
#  ('polit', np.float64(1.0)),
#  ('izzat', np.float64(1.0)),
#  ('wese', np.float64(1.0)),
#  ('trust', np.float64(1.0)),
#  ('khawateen', np.float64(1.0)),
#  ('k', np.float64(1.0)),
#  ('sath', np.float64(1.0)),
#  ('mana', np.float64(1.0)),
#  ('kar', np.float64(1.0)),
#  ('deya', np.float64(1.0)),
#  ('sort', np.float64(1.0)),
#  ('smart', np.float64(1.0)),
#  ('hair', np.float64(1.0)),
#  ('tbh', np.float64(1.0)),
#  ('jacob', np.float64(1.0)),
#  ('g', np.float64(1.0)),
#  ('upgrad', np.float64(1.0)),
#  ('tee', np.float64(1.0)),
#  ('famili', np.float64(1.0)),
#  ('person', np.float64(1.0)),
#  ('two', np.float64(1.0)),
#  ('convers', np.float64(1.0)),
#  ('onlin', np.float64(1.0)),
#  ('mclaren', np.float64(1.0)),
#  ('fridayfeel', np.float64(1.0)),
#  ('tgif', np.float64(1.0)),
#  ('squar', np.float64(1.0)),
#  ('enix', np.float64(1.0)),
#  ('bissmillah', np.float64(1.0)),
#  ('ya', np.float64(1.0)),
#  ('allah', np.float64(1.0)),
#  ("we'r", np.float64(1.0)),
#  ('socent', np.float64(1.0)),
#  ('startup', np.float64(1.0)),
#  ('drop', np.float64(1.0)),
#  ('your', np.float64(1.0)),
#  ('arnd', np.float64(1.0)),
#  ('town', np.float64(1.0)),
#  ('basic', np.float64(1.0)),
#  ('piss', np.float64(1.0)),
#  ('cup', np.float64(1.0)),
#  ('also', np.float64(1.0)),
#  ('terribl', np.float64(1.0)),
#  ('complic', np.float64(1.0)),
#  ('discuss', np.float64(1.0)),
#  ('snapchat', np.float64(1.0)),
#  ('lynettelow', np.float64(1.0)),
#  ('kikmenow', np.float64(1.0)),
#  ('snapm', np.float64(1.0)),
#  ('hot', np.float64(1.0)),
#  ('amazon', np.float64(1.0)),
#  ('kikmeguy', np.float64(1.0)),
#  ('defin', np.float64(1.0)),
#  ('grow', np.float64(1.0)),
#  ('sport', np.float64(1.0)),
#  ('rt', np.float64(1.0)),
#  ('rakyat', np.float64(1.0)),
#  ('write', np.float64(1.0)),
#  ('sinc', np.float64(1.0)),
#  ('mention', np.float64(1.0)),
#  ('fli', np.float64(1.0)),
#  ('fish', np.float64(1.0)),
#  ('promot', np.float64(1.0)),
#  ('post', np.float64(1.0)),
#  ('cyber', np.float64(1.0)),
#  ('ourdaughtersourprid', np.float64(1.0)),
#  ('mypapamyprid', np.float64(1.0)),
#  ('papa', np.float64(1.0)),
#  ('coach', np.float64(1.0)),
#  ('posit', np.float64(1.0)),
#  ('kha', np.float64(1.0)),
#  ('atleast', np.float64(1.0)),
#  ('x39', np.float64(1.0)),
#  ('mango', np.float64(1.0)),
#  ("lassi'", np.float64(1.0)),
#  ("monty'", np.float64(1.0)),
#  ('marvel', np.float64(1.0)),
#  ('though', np.float64(1.0)),
#  ('suspect', np.float64(1.0)),
#  ('meant', np.float64(1.0)),
#  ('24', np.float64(1.0)),
#  ('hr', np.float64(1.0)),
#  ('touch', np.float64(1.0)),
#  ('kepler', np.float64(1.0)),
#  ('452b', np.float64(1.0)),
#  ('chalna', np.float64(1.0)),
#  ('hai', np.float64(1.0)),
#  ('thankyou', np.float64(1.0)),
#  ('hazel', np.float64(1.0)),
#  ('food', np.float64(1.0)),
#  ('brooklyn', np.float64(1.0)),
#  ('pta', np.float64(1.0)),
#  ('awak', np.float64(1.0)),
#  ('okayi', np.float64(1.0)),
#  ('awww', np.float64(1.0)),
#  ('ha', np.float64(1.0)),
#  ('doc', np.float64(1.0)),
#  ('splendid', np.float64(1.0)),
#  ('spam', np.float64(1.0)),
#  ('folder', np.float64(1.0)),
#  ('amount', np.float64(1.0)),
#  ('nigeria', np.float64(1.0)),
#  ('claim', np.float64(1.0)),
#  ('rted', np.float64(1.0)),
#  ('leg', np.float64(1.0)),
#  ('hurt', np.float64(1.0)),
#  ('bad', np.float64(1.0)),
#  ('mine', np.float64(1.0)),
#  ('saturday', np.float64(1.0)),
#  ('thaaank', np.float64(1.0)),
#  ('puhon', np.float64(1.0)),
#  ('happinesss', np.float64(1.0)),
#  ('tnc', np.float64(1.0)),
#  ('prior', np.float64(1.0)),
#  ('notif', np.float64(1.0)),
#  ('probabl', np.float64(1.0)),
#  ('funni', np.float64(1.0)),
#  ('2:22', np.float64(1.0)),
#  ('fat', np.float64(1.0)),
#  ('co', np.float64(1.0)),
#  ('ate', np.float64(1.0)),
#  ('yuna', np.float64(1.0)),
#  ('tamesid', np.float64(1.0)),
#  ('´', np.float64(1.0)),
#  ('googl', np.float64(1.0)),
#  ('account', np.float64(1.0)),
#  ('scouser', np.float64(1.0)),
#  ('everyth', np.float64(1.0)),
#  ('zoe', np.float64(1.0)),
#  ('mate', np.float64(1.0)),
#  ('liter', np.float64(1.0)),
#  ("they'r", np.float64(1.0)),
#  ('samee', np.float64(1.0)),
#  ('edgar', np.float64(1.0)),
#  ('updat', np.float64(1.0)),
#  ('log', np.float64(1.0)),
#  ('bring', np.float64(1.0)),
#  ('abe', np.float64(1.0)),
#  ('meet', np.float64(1.0)),
#  ('x38', np.float64(1.0)),
#  ('sigh', np.float64(1.0)),
#  ('dreamili', np.float64(1.0)),
#  ('pout', np.float64(1.0)),
#  ('eye', np.float64(1.0)),
#  ('quacketyquack', np.float64(1.0)),
#  ('happen', np.float64(1.0)),
#  ('phil', np.float64(1.0)),
#  ('em', np.float64(1.0)),
#  ('del', np.float64(1.0)),
#  ('rodder', np.float64(1.0)),
#  ('els', np.float64(1.0)),
#  ('play', np.float64(1.0)),
#  ('newest', np.float64(1.0)),
#  ('gamejam', np.float64(1.0)),
#  ('irish', np.float64(1.0)),
#  ('literatur', np.float64(1.0)),
#  ('inaccess', np.float64(1.0)),
#  ("kareena'", np.float64(1.0)),
#  ('fan', np.float64(1.0)),
#  ('brain', np.float64(1.0)),
#  ('dot', np.float64(1.0)),
#  ('braindot', np.float64(1.0)),
#  ('fair', np.float64(1.0)),
#  ('rush', np.float64(1.0)),
#  ('either', np.float64(1.0)),
#  ('brandi', np.float64(1.0)),
#  ('18', np.float64(1.0)),
#  ('carniv', np.float64(1.0)),
#  ('men', np.float64(1.0)),
#  ('put', np.float64(1.0)),
#  ('mask', np.float64(1.0)),
#  ('xavier', np.float64(1.0)),
#  ('forneret', np.float64(1.0)),
#  ('jennif', np.float64(1.0)),
#  ('site', np.float64(1.0)),
#  ('free', np.float64(1.0)),
#  ('50.000', np.float64(1.0)),
#  ('8', np.float64(1.0)),
#  ('ball', np.float64(1.0)),
#  ('pool', np.float64(1.0)),
#  ('coin', np.float64(1.0)),
#  ('edit', np.float64(1.0)),
#  ('trish', np.float64(1.0)),
#  ('♥', np.float64(1.0)),
#  ('grate', np.float64(1.0)),
#  ('three', np.float64(1.0)),
#  ('comment', np.float64(1.0)),
#  ('wakeup', np.float64(1.0)),
#  ('besid', np.float64(1.0)),
#  ('dirti', np.float64(1.0)),
#  ('sex', np.float64(1.0)),
#  ('lmaooo', np.float64(1.0)),
#  ('😤', np.float64(1.0)),
#  ('loui', np.float64(1.0)),
#  ("he'", np.float64(1.0)),
#  ('throw', np.float64(1.0)),
#  ('caus', np.float64(1.0)),
#  ('inspir', np.float64(1.0)),
#  ('ff', np.float64(1.0)),
#  ('twoof', np.float64(1.0)),
#  ('gr8', np.float64(1.0)),
#  ('wkend', np.float64(1.0)),
#  ('kind', np.float64(1.0)),
#  ('exhaust', np.float64(1.0)),
#  ('word', np.float64(1.0)),
#  ('cheltenham', np.float64(1.0)),
#  ('area', np.float64(1.0)),
#  ('kale', np.float64(1.0)),
#  ('crisp', np.float64(1.0)),
#  ('ruin', np.float64(1.0)),
#  ('x37', np.float64(1.0)),
#  ('open', np.float64(1.0)),
#  ('worldwid', np.float64(1.0)),
#  ('outta', np.float64(1.0)),
#  ('sfvbeta', np.float64(1.0)),
#  ('vantast', np.float64(1.0)),
#  ('xcylin', np.float64(1.0)),
#  ('bundl', np.float64(1.0)),
#  ('show', np.float64(1.0)),
#  ('internet', np.float64(1.0)),
#  ('price', np.float64(1.0)),
#  ('realisticli', np.float64(1.0)),
#  ('pay', np.float64(1.0)),
#  ('net', np.float64(1.0)),
#  ('educ', np.float64(1.0)),
#  ('power', np.float64(1.0)),
#  ('weapon', np.float64(1.0)),
#  ('nelson', np.float64(1.0)),
#  ('mandela', np.float64(1.0)),
#  ('recent', np.float64(1.0)),
#  ('j', np.float64(1.0)),
#  ('chenab', np.float64(1.0)),
#  ('flow', np.float64(1.0)),
#  ('pakistan', np.float64(1.0)),
#  ('incredibleindia', np.float64(1.0)),
#  ('teenchoic', np.float64(1.0)),
#  ('choiceinternationalartist', np.float64(1.0)),
#  ('superjunior', np.float64(1.0)),
#  ('caught', np.float64(1.0)),
#  ('first', np.float64(1.0)),
#  ('salmon', np.float64(1.0)),
#  ('super-blend', np.float64(1.0)),
#  ('project', np.float64(1.0)),
#  ('youth@bipolaruk.org.uk', np.float64(1.0)),
#  ('awesom', np.float64(1.0)),
#  ('stream', np.float64(1.0)),
#  ('artist', np.float64(1.0)),
#  ('alma', np.float64(1.0)),
#  ('mater', np.float64(1.0)),
#  ('highschoolday', np.float64(1.0)),
#  ('clientvisit', np.float64(1.0)),
#  ('faith', np.float64(1.0)),
#  ('christian', np.float64(1.0)),
#  ('school', np.float64(1.0)),
#  ('lizaminnelli', np.float64(1.0)),
#  ('upcom', np.float64(1.0)),
#  ('uk', np.float64(1.0)),
#  ('😄', np.float64(1.0)),
#  ('singl', np.float64(1.0)),
#  ('hill', np.float64(1.0)),
#  ('everi', np.float64(1.0)),
#  ('beat', np.float64(1.0)),
#  ('wrong', np.float64(1.0)),
#  ('readi', np.float64(1.0)),
#  ('natur', np.float64(1.0)),
#  ('pefumeri', np.float64(1.0)),
#  ...]

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
# UNQ_C2 GRADED FUNCTION: train_naive_bayes

def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels corresponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    ### START CODE HERE ###

    # calculate V, the number of unique words in the vocabulary
    vocab = { pair[0] for pair in freqs }
    V = len(vocab)     

    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:

            # Increment the number of positive words by the count for this (word, label) pair
            N_pos += freqs[pair]

        # else, the label is negative
        else:

            # increment the number of negative words by the count for this (word,label) pair
            N_neg += freqs[pair]
    
    # Calculate D, the number of documents
    D = len(train_y)

    # Calculate D_pos, the number of positive documents
    D_pos = np.sum(train_y)

    # Calculate D_neg, the number of negative documents
    D_neg = D - D_pos
    
    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)
    
    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = lookup(freqs, word, 1)
        freq_neg = lookup(freqs, word, 0)

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    ### END CODE HERE ###

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9161

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9165

# %%
# Test your function
w2_unittest.test_train_naive_bayes(train_naive_bayes, freqs, train_x, train_y)
# Out:
# Wrong number of keys in loglikelihood dictionary.
# 	Expected: 9165.
# 	Got: 9161.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Test your function
# ----> 2 w2_unittest.test_train_naive_bayes(train_naive_bayes, freqs, train_x, train_y)
#
# File /mnt/p/projects/programming/Python/Natural Language Processing Specialization/Course 1 - Natural Language Processing with Classification and Vector Spaces/Week 2- Naive bayes/Assignment/w2_unittest.py:371, in test_train_naive_bayes(target, freqs, train_x, train_y)
#     368 count_good = 0
#     369 for key, value in test_case["expected"]["loglikelihood"].items():
# --> 371     if np.isclose(result2[key], value):
#     372         count_good += 1
#     374 try:
#
# KeyError: 'े'

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test your Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Exercise 3 - naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 GRADED FUNCTION: naive_bayes_predict

def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    ### START CODE HERE ###
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    ### END CODE HERE ###

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.557492820301094

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.55
# - The sentiment is positive.

# %%
# Test your function
w2_unittest.test_naive_bayes_predict(naive_bayes_predict)
# Out:
#  All tests passed

# %%
# Experiment with your own tweet.
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.1652737774400095

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 GRADED FUNCTION: test_naive_bayes

def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    ### START CODE HERE ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.mean(np.abs(y_hats - test_y))

    # Accuracy is 1 minus the error
    accuracy = 1 - error

    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9955

# %% [markdown]
# **Expected Accuracy**:
#
# `Naive Bayes accuracy = 0.9955`

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.14
# I am bad -> -1.31
# this movie should have been great. -> 2.12
# great -> 2.13
# great great -> 4.26
# great great great -> 6.39
# great great great great -> 8.52

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.14
# - I am bad -> -1.31
# - this movie should have been great. -> 2.12
# - great -> 2.13
# - great great -> 4.26
# - great great great -> 6.39
# - great great great great -> 8.52

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# np.float64(-8.837962482271395)

# %%
# Test your function
w2_unittest.unittest_test_naive_bayes(test_naive_bayes, test_x, test_y)
# Out:
# Wrong output value for accuracy.
# 	Expected: 0.9955.
# 	Got: 0.973.
# Wrong output value for accuracy.
# 	Expected: 0.995.
# 	Got: 0.97.
# Wrong output value for accuracy.
# 	Expected: 0.995.
# 	Got: 0.975.
# Wrong output value for accuracy.
# 	Expected: 0.996.
# 	Got: 0.968.
# Wrong output value for accuracy.
# 	Expected: 0.996.
# 	Got: 0.976.
#  0  Tests passed
#  5  Tests failed

# %% [markdown]
# <a name='4'></a>
# ## 4 - Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Exercise 5 - get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 GRADED FUNCTION: get_ratio

def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    ### START CODE HERE ###
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs, word, 1)
    
    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs, word, 0)
    
    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] = (pos_neg_ratio['positive'] + 1) / (pos_neg_ratio['negative'] + 1)
    ### END CODE HERE ###
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 162, 'negative': 18, 'ratio': 8.578947368421053}

# %%
# Test your function
w2_unittest.test_get_ratio(get_ratio, freqs)
# Out:
#  All tests passed

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
# UNQ_C9 GRADED FUNCTION: get_words_by_threshold

def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    ### START CODE HERE ###
    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs, word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # otherwise, do not include this word in the list (do nothing)

    ### END CODE HERE ###
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {':(': {'positive': 1, 'negative': 3675, 'ratio': 0.000544069640914037},
#  ':-(': {'positive': 0, 'negative': 386, 'ratio': 0.002583979328165375},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.047619047619047616},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.022727272727272728},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '♛': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  '》': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776}}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0, 'ratio': 24.0},
#  'commun': {'positive': 27, 'negative': 1, 'ratio': 14.0},
#  ':)': {'positive': 2960, 'negative': 2, 'ratio': 987.0},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0, 'ratio': 17.0},
#  ':d': {'positive': 523, 'negative': 0, 'ratio': 524.0},
#  ':p': {'positive': 105, 'negative': 0, 'ratio': 106.0},
#  'influenc': {'positive': 16, 'negative': 0, 'ratio': 17.0},
#  ':-)': {'positive': 552, 'negative': 0, 'ratio': 553.0},
#  "here'": {'positive': 20, 'negative': 0, 'ratio': 21.0},
#  'youth': {'positive': 14, 'negative': 0, 'ratio': 15.0},
#  'bam': {'positive': 44, 'negative': 0, 'ratio': 45.0},
#  'warsaw': {'positive': 44, 'negative': 0, 'ratio': 45.0},
#  'shout': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  ';)': {'positive': 22, 'negative': 0, 'ratio': 23.0},
#  'stat': {'positive': 51, 'negative': 0, 'ratio': 52.0},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 11.6},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 14.0},
#  'blog': {'positive': 27, 'negative': 0, 'ratio': 28.0},
#  'fav': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'fantast': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'fback': {'positive': 26, 'negative': 0, 'ratio': 27.0},
#  'pleasur': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  '←': {'positive': 9, 'negative': 0, 'ratio': 10.0},
#  'aqui': {'positive': 9, 'negative': 0, 'ratio': 10.0}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like glad, community, arrives, tend to be found in the positive tweets.

# %%
# Test your function
w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /mnt/p/projects/programming/Python/Natural Language Processing Specialization/Course 1 - Natural Language Processing with Classification and Vector Spaces/Week 2- Naive bayes/Assignment/w2_unittest.py:781, in test_get_words_by_threshold(target, freqs)
#     780 try:
# --> 781     assert np.isclose(result[key][sec_key], sec_value)
#     782     successful_cases += 1
#
# KeyError: ':D'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Test your function
# ----> 2 w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
#
# File /mnt/p/projects/programming/Python/Natural Language Processing Specialization/Course 1 - Natural Language Processing with Classification and Vector Spaces/Week 2- Naive bayes/Assignment/w2_unittest.py:788, in test_get_words_by_threshold(target, freqs)
#     782                 successful_cases += 1
#     783             except:
#     784                 failed_cases.append(
#     785                     {
#     786                         "name": test_case["name"],
#     787                         "expected": {key: {sec_key: sec_value}},
# --> 788                         "got": {key: result[key][sec_key]},
#     789                     }
#     790                 )
#     791                 print(
#     792                     f"Wrong output values.\n\tExpected: {failed_cases[-1].get('expected')}.\n\tGot: {failed_cases[-1].get('got')}."
#     793                 )
#     795 if len(failed_cases) == 0:
#
# KeyError: ':D'

# %% [markdown]
# <a name='5'></a>
# ## 5 - Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :d'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 9.570227756170972

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
